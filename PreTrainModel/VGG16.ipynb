# %%
import os
import cv2
import shutil
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Dense, GlobalAveragePooling2D, GlobalMaxPooling2D, Multiply, Add, Concatenate, Activation, BatchNormalization, MaxPooling2D, Input, DepthwiseConv2D, Lambda, LeakyReLU, Reshape, UpSampling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import AUC, Precision, Recall
from tensorflow.keras.layers import Dropout, Flatten
from sklearn.metrics import precision_recall_curve, roc_curve, auc, f1_score
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.metrics import Metric
from tensorflow.keras.layers import Layer
from tensorflow.keras.losses import Loss
from keras.regularizers import l2
import seaborn as sns
from tensorflow.keras.applications.resnet50 import ResNet50
import keras.backend as K
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras.applications import ResNet50, InceptionV3, VGG16, DenseNet121, MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from sklearn.metrics import cohen_kappa_score
import pandas as pd
# Out:
# 2023-12-12 23:01:11.204166: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-12 23:01:11.981681: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Data set generation and data enhancement

# %%
train_dir = '../dsForBinary/train'
validation_dir = '../dsForBinary/validation'
test_dir = '../dsForBinary/test'

def preprocessing_function(image):
    def bilateral_filter(image):
        return cv2.bilateralFilter(image, d=21, sigmaColor=10, sigmaSpace=10)
    filtered_image = tf.numpy_function(bilateral_filter, [image], tf.float32)
    filtered_image.set_shape(image.shape)
    return filtered_image


train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.15,
    fill_mode='nearest',
    preprocessing_function=preprocessing_function
)
validation_datagen = ImageDataGenerator(rescale=1.0/255,rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.15,
    fill_mode='nearest',
    # preprocessing_function=preprocessing_function
    )
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 2179 images belonging to 2 classes.
# Found 548 images belonging to 2 classes.
# Found 552 images belonging to 2 classes.

# %%
def display_image_augmentation_horizontal(original_gen, augmentation_gen, num_samples=5):
    fig, axs = plt.subplots(2, num_samples, figsize=(num_samples * 3, 6))

    for i in range(num_samples):
        original_img = next(original_gen)[0][0]
        if np.max(original_img) <= 1:
            original_img = (original_img * 255).astype('uint8')

        axs[0, i].imshow(original_img)
        axs[0, i].set_title(f'Original {i+1}')
        axs[0, i].axis('off')

        augmented_img = next(augmentation_gen.flow(np.expand_dims(original_img, 0), batch_size=1))[0]
        augmented_img = (augmented_img * 255).astype('uint8')

        axs[1, i].imshow(augmented_img)
        axs[1, i].set_title(f'Augmented {i+1}')
        axs[1, i].axis('off')

    plt.tight_layout()
    plt.show()

display_image_augmentation_horizontal(test_generator, train_datagen, num_samples=5)
# Out:
# 2023-12-12 23:01:13.865694: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 23:01:13.874429: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 23:01:13.874659: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 23:01:13.876772: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 23:01:13.876957: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 23:01:13.877116: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 23:01:14.321720: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 23:01:14.321961: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 23:01:14.322133: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 23:01:14.322244: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-12-12 23:01:14.322274: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 40596 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:10:00.0, compute capability: 8.6

# %% [markdown]
# # Creating models and attention mechanisms

# %% [markdown]
# # Model fitting

# %%
def create_model(base_model, num_classes=2, train_base_model=False):
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    
    if not train_base_model:
        for layer in base_model.layers:
            layer.trainable = False
    
    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', AUC(name='auc'), Precision(name='precision'), Recall(name='recall')])
    return model

vgg16_model = create_model(VGG16(weights='imagenet', include_top=False), train_base_model=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 6s 0us/step

# %%
def train_model(model, train_data, val_data, epochs=50):
    history = model.fit(
        train_data,
        validation_data=val_data,
        epochs=epochs,
        verbose=1
    )
    return history

# %%
vgg16_history = train_model(vgg16_model, train_generator, validation_generator)
# Out:
# Epoch 1/50
# 2023-12-12 23:01:26.950330: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-12-12 23:01:28.054431: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-12 23:01:28.062226: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x61a6640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-12 23:01:28.062294: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-12-12 23:01:28.070120: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-12 23:01:28.212755: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 69/69 [==============================] - 95s 1s/step - loss: 0.3164 - accuracy: 0.8807 - auc: 0.9394 - precision: 0.8807 - recall: 0.8807 - val_loss: 0.3091 - val_accuracy: 0.8796 - val_auc: 0.9417 - val_precision: 0.8796 - val_recall: 0.8796
# Epoch 3/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.3003 - accuracy: 0.8862 - auc: 0.9437 - precision: 0.8862 - recall: 0.8862 - val_loss: 0.2856 - val_accuracy: 0.8905 - val_auc: 0.9493 - val_precision: 0.8905 - val_recall: 0.8905
# Epoch 4/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2839 - accuracy: 0.8949 - auc: 0.9487 - precision: 0.8949 - recall: 0.8949 - val_loss: 0.2657 - val_accuracy: 0.9033 - val_auc: 0.9550 - val_precision: 0.9033 - val_recall: 0.9033
# Epoch 5/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2672 - accuracy: 0.9045 - auc: 0.9541 - precision: 0.9045 - recall: 0.9045 - val_loss: 0.2535 - val_accuracy: 0.9033 - val_auc: 0.9608 - val_precision: 0.9033 - val_recall: 0.9033
# Epoch 6/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2698 - accuracy: 0.8986 - auc: 0.9541 - precision: 0.8986 - recall: 0.8986 - val_loss: 0.3271 - val_accuracy: 0.8686 - val_auc: 0.9343 - val_precision: 0.8686 - val_recall: 0.8686
# Epoch 7/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2802 - accuracy: 0.9009 - auc: 0.9500 - precision: 0.9009 - recall: 0.9009 - val_loss: 0.2802 - val_accuracy: 0.8996 - val_auc: 0.9503 - val_precision: 0.8996 - val_recall: 0.8996
# Epoch 8/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2526 - accuracy: 0.9133 - auc: 0.9590 - precision: 0.9133 - recall: 0.9133 - val_loss: 0.2549 - val_accuracy: 0.8942 - val_auc: 0.9603 - val_precision: 0.8942 - val_recall: 0.8942
# Epoch 9/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2455 - accuracy: 0.9114 - auc: 0.9608 - precision: 0.9114 - recall: 0.9114 - val_loss: 0.2494 - val_accuracy: 0.9179 - val_auc: 0.9601 - val_precision: 0.9179 - val_recall: 0.9179
# Epoch 10/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2263 - accuracy: 0.9128 - auc: 0.9674 - precision: 0.9128 - recall: 0.9128 - val_loss: 0.2491 - val_accuracy: 0.9069 - val_auc: 0.9604 - val_precision: 0.9069 - val_recall: 0.9069
# Epoch 11/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2533 - accuracy: 0.9082 - auc: 0.9594 - precision: 0.9082 - recall: 0.9082 - val_loss: 0.2916 - val_accuracy: 0.8905 - val_auc: 0.9486 - val_precision: 0.8905 - val_recall: 0.8905
# Epoch 12/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2337 - accuracy: 0.9169 - auc: 0.9646 - precision: 0.9169 - recall: 0.9169 - val_loss: 0.2275 - val_accuracy: 0.9179 - val_auc: 0.9671 - val_precision: 0.9179 - val_recall: 0.9179
# Epoch 13/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2246 - accuracy: 0.9201 - auc: 0.9673 - precision: 0.9201 - recall: 0.9201 - val_loss: 0.2307 - val_accuracy: 0.9179 - val_auc: 0.9653 - val_precision: 0.9179 - val_recall: 0.9179
# Epoch 14/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2224 - accuracy: 0.9234 - auc: 0.9672 - precision: 0.9234 - recall: 0.9234 - val_loss: 0.2457 - val_accuracy: 0.9142 - val_auc: 0.9607 - val_precision: 0.9142 - val_recall: 0.9142
# Epoch 15/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2328 - accuracy: 0.9192 - auc: 0.9660 - precision: 0.9192 - recall: 0.9192 - val_loss: 0.2448 - val_accuracy: 0.9051 - val_auc: 0.9628 - val_precision: 0.9051 - val_recall: 0.9051
# Epoch 16/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2277 - accuracy: 0.9211 - auc: 0.9657 - precision: 0.9211 - recall: 0.9211 - val_loss: 0.2535 - val_accuracy: 0.9051 - val_auc: 0.9593 - val_precision: 0.9051 - val_recall: 0.9051
# Epoch 17/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2131 - accuracy: 0.9261 - auc: 0.9697 - precision: 0.9261 - recall: 0.9261 - val_loss: 0.2434 - val_accuracy: 0.9106 - val_auc: 0.9623 - val_precision: 0.9106 - val_recall: 0.9106
# Epoch 18/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2051 - accuracy: 0.9279 - auc: 0.9723 - precision: 0.9279 - recall: 0.9279 - val_loss: 0.2276 - val_accuracy: 0.9033 - val_auc: 0.9676 - val_precision: 0.9033 - val_recall: 0.9033
# Epoch 19/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2208 - accuracy: 0.9206 - auc: 0.9684 - precision: 0.9206 - recall: 0.9206 - val_loss: 0.2644 - val_accuracy: 0.8996 - val_auc: 0.9555 - val_precision: 0.8996 - val_recall: 0.8996
# Epoch 20/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2037 - accuracy: 0.9293 - auc: 0.9729 - precision: 0.9293 - recall: 0.9293 - val_loss: 0.2510 - val_accuracy: 0.9051 - val_auc: 0.9606 - val_precision: 0.9051 - val_recall: 0.9051
# Epoch 21/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.2077 - accuracy: 0.9266 - auc: 0.9720 - precision: 0.9266 - recall: 0.9266 - val_loss: 0.2231 - val_accuracy: 0.9270 - val_auc: 0.9667 - val_precision: 0.9270 - val_recall: 0.9270
# Epoch 22/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.2064 - accuracy: 0.9238 - auc: 0.9728 - precision: 0.9238 - recall: 0.9238 - val_loss: 0.2143 - val_accuracy: 0.9234 - val_auc: 0.9693 - val_precision: 0.9234 - val_recall: 0.9234
# Epoch 23/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1989 - accuracy: 0.9261 - auc: 0.9747 - precision: 0.9261 - recall: 0.9261 - val_loss: 0.2169 - val_accuracy: 0.9252 - val_auc: 0.9701 - val_precision: 0.9252 - val_recall: 0.9252
# Epoch 24/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2075 - accuracy: 0.9257 - auc: 0.9720 - precision: 0.9257 - recall: 0.9257 - val_loss: 0.2596 - val_accuracy: 0.9051 - val_auc: 0.9605 - val_precision: 0.9051 - val_recall: 0.9051
# Epoch 25/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2179 - accuracy: 0.9206 - auc: 0.9694 - precision: 0.9206 - recall: 0.9206 - val_loss: 0.2293 - val_accuracy: 0.9161 - val_auc: 0.9665 - val_precision: 0.9161 - val_recall: 0.9161
# Epoch 26/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1984 - accuracy: 0.9275 - auc: 0.9743 - precision: 0.9275 - recall: 0.9275 - val_loss: 0.2177 - val_accuracy: 0.9343 - val_auc: 0.9674 - val_precision: 0.9343 - val_recall: 0.9343
# Epoch 27/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1926 - accuracy: 0.9307 - auc: 0.9756 - precision: 0.9307 - recall: 0.9307 - val_loss: 0.2164 - val_accuracy: 0.9252 - val_auc: 0.9690 - val_precision: 0.9252 - val_recall: 0.9252
# Epoch 28/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2031 - accuracy: 0.9279 - auc: 0.9735 - precision: 0.9279 - recall: 0.9279 - val_loss: 0.2170 - val_accuracy: 0.9234 - val_auc: 0.9711 - val_precision: 0.9234 - val_recall: 0.9234
# Epoch 29/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1905 - accuracy: 0.9335 - auc: 0.9759 - precision: 0.9335 - recall: 0.9335 - val_loss: 0.2196 - val_accuracy: 0.9270 - val_auc: 0.9685 - val_precision: 0.9270 - val_recall: 0.9270
# Epoch 30/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1963 - accuracy: 0.9335 - auc: 0.9751 - precision: 0.9335 - recall: 0.9335 - val_loss: 0.2021 - val_accuracy: 0.9380 - val_auc: 0.9718 - val_precision: 0.9380 - val_recall: 0.9380
# Epoch 31/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1903 - accuracy: 0.9307 - auc: 0.9770 - precision: 0.9307 - recall: 0.9307 - val_loss: 0.2177 - val_accuracy: 0.9234 - val_auc: 0.9687 - val_precision: 0.9234 - val_recall: 0.9234
# Epoch 32/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1950 - accuracy: 0.9321 - auc: 0.9752 - precision: 0.9321 - recall: 0.9321 - val_loss: 0.2157 - val_accuracy: 0.9234 - val_auc: 0.9685 - val_precision: 0.9234 - val_recall: 0.9234
# Epoch 33/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2104 - accuracy: 0.9284 - auc: 0.9709 - precision: 0.9284 - recall: 0.9284 - val_loss: 0.2200 - val_accuracy: 0.9270 - val_auc: 0.9679 - val_precision: 0.9270 - val_recall: 0.9270
# Epoch 34/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2026 - accuracy: 0.9298 - auc: 0.9734 - precision: 0.9298 - recall: 0.9298 - val_loss: 0.2093 - val_accuracy: 0.9252 - val_auc: 0.9712 - val_precision: 0.9252 - val_recall: 0.9252
# Epoch 35/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1809 - accuracy: 0.9335 - auc: 0.9786 - precision: 0.9335 - recall: 0.9335 - val_loss: 0.2304 - val_accuracy: 0.9179 - val_auc: 0.9661 - val_precision: 0.9179 - val_recall: 0.9179
# Epoch 36/50
# 69/69 [==============================] - 96s 1s/step - loss: 0.1830 - accuracy: 0.9417 - auc: 0.9773 - precision: 0.9417 - recall: 0.9417 - val_loss: 0.2028 - val_accuracy: 0.9307 - val_auc: 0.9738 - val_precision: 0.9307 - val_recall: 0.9307
# Epoch 37/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1859 - accuracy: 0.9380 - auc: 0.9772 - precision: 0.9380 - recall: 0.9380 - val_loss: 0.2293 - val_accuracy: 0.9234 - val_auc: 0.9672 - val_precision: 0.9234 - val_recall: 0.9234
# Epoch 38/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1879 - accuracy: 0.9376 - auc: 0.9771 - precision: 0.9376 - recall: 0.9376 - val_loss: 0.2469 - val_accuracy: 0.9106 - val_auc: 0.9618 - val_precision: 0.9106 - val_recall: 0.9106
# Epoch 39/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1925 - accuracy: 0.9344 - auc: 0.9752 - precision: 0.9344 - recall: 0.9344 - val_loss: 0.2397 - val_accuracy: 0.9161 - val_auc: 0.9659 - val_precision: 0.9161 - val_recall: 0.9161
# Epoch 40/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1967 - accuracy: 0.9316 - auc: 0.9746 - precision: 0.9316 - recall: 0.9316 - val_loss: 0.2385 - val_accuracy: 0.9161 - val_auc: 0.9647 - val_precision: 0.9161 - val_recall: 0.9161
# Epoch 41/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1858 - accuracy: 0.9339 - auc: 0.9780 - precision: 0.9339 - recall: 0.9339 - val_loss: 0.2372 - val_accuracy: 0.9106 - val_auc: 0.9637 - val_precision: 0.9106 - val_recall: 0.9106
# Epoch 42/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1773 - accuracy: 0.9371 - auc: 0.9791 - precision: 0.9371 - recall: 0.9371 - val_loss: 0.2151 - val_accuracy: 0.9288 - val_auc: 0.9691 - val_precision: 0.9288 - val_recall: 0.9288
# Epoch 43/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1916 - accuracy: 0.9344 - auc: 0.9759 - precision: 0.9344 - recall: 0.9344 - val_loss: 0.1991 - val_accuracy: 0.9215 - val_auc: 0.9757 - val_precision: 0.9215 - val_recall: 0.9215
# Epoch 44/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1859 - accuracy: 0.9390 - auc: 0.9767 - precision: 0.9390 - recall: 0.9390 - val_loss: 0.1999 - val_accuracy: 0.9215 - val_auc: 0.9741 - val_precision: 0.9215 - val_recall: 0.9215
# Epoch 45/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1892 - accuracy: 0.9376 - auc: 0.9763 - precision: 0.9376 - recall: 0.9376 - val_loss: 0.2055 - val_accuracy: 0.9234 - val_auc: 0.9726 - val_precision: 0.9234 - val_recall: 0.9234
# Epoch 46/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1775 - accuracy: 0.9380 - auc: 0.9791 - precision: 0.9380 - recall: 0.9380 - val_loss: 0.2164 - val_accuracy: 0.9252 - val_auc: 0.9706 - val_precision: 0.9252 - val_recall: 0.9252
# Epoch 47/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1727 - accuracy: 0.9426 - auc: 0.9796 - precision: 0.9426 - recall: 0.9426 - val_loss: 0.2327 - val_accuracy: 0.9197 - val_auc: 0.9660 - val_precision: 0.9197 - val_recall: 0.9197
# Epoch 48/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1820 - accuracy: 0.9380 - auc: 0.9778 - precision: 0.9380 - recall: 0.9380 - val_loss: 0.1982 - val_accuracy: 0.9234 - val_auc: 0.9742 - val_precision: 0.9234 - val_recall: 0.9234
# Epoch 49/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1762 - accuracy: 0.9403 - auc: 0.9792 - precision: 0.9403 - recall: 0.9403 - val_loss: 0.3701 - val_accuracy: 0.8595 - val_auc: 0.9343 - val_precision: 0.8595 - val_recall: 0.8595
# Epoch 50/50
# 69/69 [==============================] - 99s 1s/step - loss: 0.1851 - accuracy: 0.9376 - auc: 0.9770 - precision: 0.9376 - recall: 0.9376 - val_loss: 0.2124 - val_accuracy: 0.9307 - val_auc: 0.9718 - val_precision: 0.9307 - val_recall: 0.9307

# %%
evaluation_result = vgg16_model.evaluate(test_generator)
# Out:
# 18/18 [==============================] - 1s 64ms/step - loss: 0.1952 - accuracy: 0.9293 - auc: 0.9748 - precision: 0.9293 - recall: 0.9293

# %%
def plot_metrics(epochs, train_metric, val_metric, subplot_title, y_label):
    plt.plot(epochs, train_metric, label='Training ' + y_label)
    plt.plot(epochs, val_metric, label='Validation ' + y_label)
    plt.title(subplot_title)
    plt.xlabel('Epoch')
    plt.ylabel(y_label)
    plt.legend()

metrics = {
    'Accuracy': ('accuracy', 'val_accuracy'),
    'Loss': ('loss', 'val_loss'),
    'AUC': ('auc', 'val_auc'),
    'Precision': ('precision', 'val_precision'),
    'Recall': ('recall', 'val_recall')
}

epochs = range(len(vgg16_history.history['accuracy']))

plt.figure(figsize=(12, 12))

for i, (metric_name, (train_key, val_key)) in enumerate(metrics.items(), 1):
    plt.subplot(3, 2, i)
    plot_metrics(epochs, vgg16_history.history[train_key], vgg16_history.history[val_key], f'Training and Validation {metric_name}', metric_name)

plt.tight_layout()
plt.show()

# %%
vgg16_model.save(r'model_vgg16.h5')

loaded_model = tf.keras.models.load_model(r'model_vgg16.h5')

evaluation_result = loaded_model.evaluate(test_generator)
# Out:
# /environment/miniconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 18/18 [==============================] - 1s 55ms/step - loss: 0.1952 - accuracy: 0.9293 - auc: 0.9748 - precision: 0.9293 - recall: 0.9293

# %%
all_images = []
all_true_labels = []

for _ in range(test_generator.samples // test_generator.batch_size):
    images, true_labels = next(test_generator)
    all_images.extend(images)
    all_true_labels.extend(true_labels)

all_images = np.array(all_images)
all_true_labels = np.argmax(np.array(all_true_labels), axis=1)
predictions = loaded_model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)


conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 17/17 [==============================] - 1s 36ms/step

# %%
TP = conf_matrix[1, 1]
TN = conf_matrix[0, 0]
FP = conf_matrix[0, 1]
FN = conf_matrix[1, 0]

recall = TP / (TP + FN)
precision = TP / (TP + FP)
sensitivity = recall
specificity = TN / (TN + FP)

plt.bar(['Recall', 'Precision', 'Sensitivity', 'Specificity'], [recall, precision, sensitivity, specificity])
plt.ylim([0, 1])
plt.ylabel('Score')
plt.title('Evaluation Metrics')
plt.show()

print(recall, precision, sensitivity, specificity)
# Out:
# 0.953307392996109 0.9074074074074074 0.953307392996109 0.9049429657794676

# %%
predicted_labels = np.argmax(predictions, axis=1)
fpr, tpr, thresholds = roc_curve(all_true_labels, predictions[:, 1])  
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
precision, recall, _ = precision_recall_curve(all_true_labels, predictions[:, 1])
pr_auc = auc(recall, precision)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='darkorange', lw=2, label=f'PR curve (area = {pr_auc:.2f})')
# plt.plot([0, 1], [1, 0], color='navy', lw=2, linestyle='--') 
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
f1 = f1_score(all_true_labels, predicted_labels)

print("F1 Score:", f1)
# Out:
# F1 Score: 0.9297912713472486

# %%
kappa_score = cohen_kappa_score(all_true_labels, predicted_labels)

# Print the Kappa score
print("Kappa Score:", kappa_score)
# Out:
# Kappa Score: 0.8577554339790034

# %%
history_df1 = pd.DataFrame(vgg16_history.history)

history_df1.to_csv('vgg16_history.csv', index=False)

# %%
precision, recall, _ = precision_recall_curve(all_true_labels, predictions[:, 1])
auc_pr = auc(recall, precision)

# 绘制AUC-PR曲线
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='darkorange', lw=2, label=f'AUC-PR = {auc_pr:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='lower left')
plt.show()
