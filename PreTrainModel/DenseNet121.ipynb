# %%
import os
import cv2
import shutil
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Dense, GlobalAveragePooling2D, GlobalMaxPooling2D, Multiply, Add, Concatenate, Activation, BatchNormalization, MaxPooling2D, Input, DepthwiseConv2D, Lambda, LeakyReLU, Reshape, UpSampling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import AUC, Precision, Recall
from tensorflow.keras.layers import Dropout, Flatten
from sklearn.metrics import precision_recall_curve, roc_curve, auc, f1_score
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.metrics import Metric
from tensorflow.keras.layers import Layer
from tensorflow.keras.losses import Loss
from keras.regularizers import l2
import seaborn as sns
from tensorflow.keras.applications.resnet50 import ResNet50
import keras.backend as K
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras.applications import ResNet50, InceptionV3, VGG16, DenseNet121, MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from sklearn.metrics import cohen_kappa_score
import pandas as pd

# %% [markdown]
# # Data set generation and data enhancement

# %%
train_dir = '../dsForBinary/train'
validation_dir = '../dsForBinary/validation'
test_dir = '../dsForBinary/test'

def preprocessing_function(image):
    def bilateral_filter(image):
        return cv2.bilateralFilter(image, d=21, sigmaColor=10, sigmaSpace=10)
    filtered_image = tf.numpy_function(bilateral_filter, [image], tf.float32)
    filtered_image.set_shape(image.shape)
    return filtered_image


train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.15,
    fill_mode='nearest',
    preprocessing_function=preprocessing_function
)
validation_datagen = ImageDataGenerator(rescale=1.0/255,rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.15,
    fill_mode='nearest',
    # preprocessing_function=preprocessing_function
    )
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 2179 images belonging to 2 classes.
# Found 548 images belonging to 2 classes.
# Found 552 images belonging to 2 classes.

# %%
def display_image_augmentation_horizontal(original_gen, augmentation_gen, num_samples=5):
    fig, axs = plt.subplots(2, num_samples, figsize=(num_samples * 3, 6))

    for i in range(num_samples):
        original_img = next(original_gen)[0][0]
        if np.max(original_img) <= 1:
            original_img = (original_img * 255).astype('uint8')

        axs[0, i].imshow(original_img)
        axs[0, i].set_title(f'Original {i+1}')
        axs[0, i].axis('off')

        augmented_img = next(augmentation_gen.flow(np.expand_dims(original_img, 0), batch_size=1))[0]
        augmented_img = (augmented_img * 255).astype('uint8')

        axs[1, i].imshow(augmented_img)
        axs[1, i].set_title(f'Augmented {i+1}')
        axs[1, i].axis('off')

    plt.tight_layout()
    plt.show()

display_image_augmentation_horizontal(test_generator, train_datagen, num_samples=5)
# Out:
# 2023-12-12 22:59:08.041708: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 22:59:08.070565: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 22:59:08.070878: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 22:59:08.073423: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 22:59:08.073706: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 22:59:08.073966: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 22:59:08.762358: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 22:59:08.762645: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 22:59:08.762818: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-12 22:59:08.762929: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-12-12 22:59:08.763026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46692 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:10:00.0, compute capability: 8.6

# %% [markdown]
# # Creating models and attention mechanisms

# %% [markdown]
# # Model fitting

# %%
def create_model(base_model, num_classes=2, train_base_model=False):
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    
    if not train_base_model:
        for layer in base_model.layers:
            layer.trainable = False
    
    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', AUC(name='auc'), Precision(name='precision'), Recall(name='recall')])
    return model

densenet121_model = create_model(DenseNet121(weights='imagenet', include_top=False), train_base_model=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 4s 0us/step

# %%
def train_model(model, train_data, val_data, epochs=50):
    history = model.fit(
        train_data,
        validation_data=val_data,
        epochs=epochs,
        verbose=1
    )
    return history

# %%
densenet121_history = train_model(densenet121_model, train_generator, validation_generator)
# Out:
# Epoch 1/50
# 2023-12-12 22:59:28.406451: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-12-12 22:59:31.086633: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-12 22:59:31.946005: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1dfa7e60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-12 22:59:31.946075: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-12-12 22:59:31.976356: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-12 22:59:32.191247: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 69/69 [==============================] - 104s 1s/step - loss: 0.3582 - accuracy: 0.8619 - auc: 0.9278 - precision: 0.8619 - recall: 0.8619 - val_loss: 0.2319 - val_accuracy: 0.9088 - val_auc: 0.9675 - val_precision: 0.9088 - val_recall: 0.9088
# Epoch 2/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.2119 - accuracy: 0.9261 - auc: 0.9709 - precision: 0.9261 - recall: 0.9261 - val_loss: 0.1996 - val_accuracy: 0.9179 - val_auc: 0.9765 - val_precision: 0.9179 - val_recall: 0.9179
# Epoch 3/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1770 - accuracy: 0.9358 - auc: 0.9800 - precision: 0.9358 - recall: 0.9358 - val_loss: 0.1786 - val_accuracy: 0.9361 - val_auc: 0.9805 - val_precision: 0.9361 - val_recall: 0.9361
# Epoch 4/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1831 - accuracy: 0.9367 - auc: 0.9781 - precision: 0.9367 - recall: 0.9367 - val_loss: 0.1754 - val_accuracy: 0.9416 - val_auc: 0.9805 - val_precision: 0.9416 - val_recall: 0.9416
# Epoch 5/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1512 - accuracy: 0.9527 - auc: 0.9841 - precision: 0.9527 - recall: 0.9527 - val_loss: 0.1756 - val_accuracy: 0.9361 - val_auc: 0.9805 - val_precision: 0.9361 - val_recall: 0.9361
# Epoch 6/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1567 - accuracy: 0.9463 - auc: 0.9839 - precision: 0.9463 - recall: 0.9463 - val_loss: 0.2050 - val_accuracy: 0.9197 - val_auc: 0.9746 - val_precision: 0.9197 - val_recall: 0.9197
# Epoch 7/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1486 - accuracy: 0.9445 - auc: 0.9857 - precision: 0.9445 - recall: 0.9445 - val_loss: 0.2490 - val_accuracy: 0.9161 - val_auc: 0.9684 - val_precision: 0.9161 - val_recall: 0.9161
# Epoch 8/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1695 - accuracy: 0.9385 - auc: 0.9818 - precision: 0.9385 - recall: 0.9385 - val_loss: 0.2688 - val_accuracy: 0.9179 - val_auc: 0.9673 - val_precision: 0.9179 - val_recall: 0.9179
# Epoch 9/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1397 - accuracy: 0.9541 - auc: 0.9867 - precision: 0.9541 - recall: 0.9541 - val_loss: 0.3040 - val_accuracy: 0.8759 - val_auc: 0.9564 - val_precision: 0.8759 - val_recall: 0.8759
# Epoch 10/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1240 - accuracy: 0.9587 - auc: 0.9892 - precision: 0.9587 - recall: 0.9587 - val_loss: 0.2578 - val_accuracy: 0.8905 - val_auc: 0.9665 - val_precision: 0.8905 - val_recall: 0.8905
# Epoch 12/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1471 - accuracy: 0.9463 - auc: 0.9863 - precision: 0.9463 - recall: 0.9463 - val_loss: 0.3112 - val_accuracy: 0.8832 - val_auc: 0.9567 - val_precision: 0.8832 - val_recall: 0.8832
# Epoch 13/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1318 - accuracy: 0.9532 - auc: 0.9885 - precision: 0.9532 - recall: 0.9532 - val_loss: 0.1825 - val_accuracy: 0.9343 - val_auc: 0.9805 - val_precision: 0.9343 - val_recall: 0.9343
# Epoch 14/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1249 - accuracy: 0.9578 - auc: 0.9898 - precision: 0.9578 - recall: 0.9578 - val_loss: 0.3915 - val_accuracy: 0.8504 - val_auc: 0.9389 - val_precision: 0.8504 - val_recall: 0.8504
# Epoch 15/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1286 - accuracy: 0.9582 - auc: 0.9882 - precision: 0.9582 - recall: 0.9582 - val_loss: 0.3972 - val_accuracy: 0.8595 - val_auc: 0.9397 - val_precision: 0.8595 - val_recall: 0.8595
# Epoch 16/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1459 - accuracy: 0.9449 - auc: 0.9868 - precision: 0.9449 - recall: 0.9449 - val_loss: 0.1671 - val_accuracy: 0.9471 - val_auc: 0.9820 - val_precision: 0.9471 - val_recall: 0.9471
# Epoch 17/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1296 - accuracy: 0.9527 - auc: 0.9887 - precision: 0.9527 - recall: 0.9527 - val_loss: 0.2178 - val_accuracy: 0.9325 - val_auc: 0.9730 - val_precision: 0.9325 - val_recall: 0.9325
# Epoch 18/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1260 - accuracy: 0.9559 - auc: 0.9892 - precision: 0.9559 - recall: 0.9559 - val_loss: 0.2384 - val_accuracy: 0.9124 - val_auc: 0.9743 - val_precision: 0.9124 - val_recall: 0.9124
# Epoch 19/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1219 - accuracy: 0.9605 - auc: 0.9893 - precision: 0.9605 - recall: 0.9605 - val_loss: 0.2310 - val_accuracy: 0.9215 - val_auc: 0.9733 - val_precision: 0.9215 - val_recall: 0.9215
# Epoch 20/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1265 - accuracy: 0.9596 - auc: 0.9890 - precision: 0.9596 - recall: 0.9596 - val_loss: 0.1974 - val_accuracy: 0.9307 - val_auc: 0.9798 - val_precision: 0.9307 - val_recall: 0.9307
# Epoch 21/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1203 - accuracy: 0.9573 - auc: 0.9902 - precision: 0.9573 - recall: 0.9573 - val_loss: 0.2081 - val_accuracy: 0.9161 - val_auc: 0.9779 - val_precision: 0.9161 - val_recall: 0.9161
# Epoch 22/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1225 - accuracy: 0.9637 - auc: 0.9889 - precision: 0.9637 - recall: 0.9637 - val_loss: 0.2577 - val_accuracy: 0.8923 - val_auc: 0.9638 - val_precision: 0.8923 - val_recall: 0.8923
# Epoch 23/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1264 - accuracy: 0.9546 - auc: 0.9890 - precision: 0.9546 - recall: 0.9546 - val_loss: 0.2874 - val_accuracy: 0.8814 - val_auc: 0.9561 - val_precision: 0.8814 - val_recall: 0.8814
# Epoch 24/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1070 - accuracy: 0.9651 - auc: 0.9916 - precision: 0.9651 - recall: 0.9651 - val_loss: 0.1651 - val_accuracy: 0.9507 - val_auc: 0.9820 - val_precision: 0.9507 - val_recall: 0.9507
# Epoch 25/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1008 - accuracy: 0.9660 - auc: 0.9929 - precision: 0.9660 - recall: 0.9660 - val_loss: 0.1928 - val_accuracy: 0.9307 - val_auc: 0.9800 - val_precision: 0.9307 - val_recall: 0.9307
# Epoch 26/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1116 - accuracy: 0.9624 - auc: 0.9908 - precision: 0.9624 - recall: 0.9624 - val_loss: 0.1846 - val_accuracy: 0.9416 - val_auc: 0.9809 - val_precision: 0.9416 - val_recall: 0.9416
# Epoch 27/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1144 - accuracy: 0.9610 - auc: 0.9905 - precision: 0.9610 - recall: 0.9610 - val_loss: 0.3079 - val_accuracy: 0.8850 - val_auc: 0.9602 - val_precision: 0.8850 - val_recall: 0.8850
# Epoch 28/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1034 - accuracy: 0.9651 - auc: 0.9929 - precision: 0.9651 - recall: 0.9651 - val_loss: 0.2405 - val_accuracy: 0.9142 - val_auc: 0.9719 - val_precision: 0.9142 - val_recall: 0.9142
# Epoch 29/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1022 - accuracy: 0.9693 - auc: 0.9920 - precision: 0.9693 - recall: 0.9693 - val_loss: 0.2190 - val_accuracy: 0.9197 - val_auc: 0.9764 - val_precision: 0.9197 - val_recall: 0.9197
# Epoch 30/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1079 - accuracy: 0.9647 - auc: 0.9914 - precision: 0.9647 - recall: 0.9647 - val_loss: 0.1333 - val_accuracy: 0.9526 - val_auc: 0.9867 - val_precision: 0.9526 - val_recall: 0.9526
# Epoch 31/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1042 - accuracy: 0.9628 - auc: 0.9922 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.3117 - val_accuracy: 0.8960 - val_auc: 0.9574 - val_precision: 0.8960 - val_recall: 0.8960
# Epoch 32/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1269 - accuracy: 0.9564 - auc: 0.9892 - precision: 0.9564 - recall: 0.9564 - val_loss: 0.5251 - val_accuracy: 0.8412 - val_auc: 0.9169 - val_precision: 0.8412 - val_recall: 0.8412
# Epoch 33/50
# 69/69 [==============================] - 94s 1s/step - loss: 0.1050 - accuracy: 0.9651 - auc: 0.9922 - precision: 0.9651 - recall: 0.9651 - val_loss: 0.1849 - val_accuracy: 0.9361 - val_auc: 0.9809 - val_precision: 0.9361 - val_recall: 0.9361
# Epoch 34/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.0865 - accuracy: 0.9720 - auc: 0.9948 - precision: 0.9720 - recall: 0.9720 - val_loss: 0.2706 - val_accuracy: 0.9197 - val_auc: 0.9666 - val_precision: 0.9197 - val_recall: 0.9197
# Epoch 35/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1134 - accuracy: 0.9601 - auc: 0.9911 - precision: 0.9601 - recall: 0.9601 - val_loss: 0.2734 - val_accuracy: 0.9234 - val_auc: 0.9656 - val_precision: 0.9234 - val_recall: 0.9234
# Epoch 36/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1049 - accuracy: 0.9688 - auc: 0.9916 - precision: 0.9688 - recall: 0.9688 - val_loss: 0.1529 - val_accuracy: 0.9507 - val_auc: 0.9852 - val_precision: 0.9507 - val_recall: 0.9507
# Epoch 37/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1098 - accuracy: 0.9637 - auc: 0.9917 - precision: 0.9637 - recall: 0.9637 - val_loss: 0.1946 - val_accuracy: 0.9325 - val_auc: 0.9813 - val_precision: 0.9325 - val_recall: 0.9325
# Epoch 38/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.0882 - accuracy: 0.9697 - auc: 0.9943 - precision: 0.9697 - recall: 0.9697 - val_loss: 0.1841 - val_accuracy: 0.9453 - val_auc: 0.9815 - val_precision: 0.9453 - val_recall: 0.9453
# Epoch 39/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.0981 - accuracy: 0.9688 - auc: 0.9928 - precision: 0.9688 - recall: 0.9688 - val_loss: 0.2276 - val_accuracy: 0.9252 - val_auc: 0.9739 - val_precision: 0.9252 - val_recall: 0.9252
# Epoch 40/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.0881 - accuracy: 0.9683 - auc: 0.9949 - precision: 0.9683 - recall: 0.9683 - val_loss: 0.1766 - val_accuracy: 0.9307 - val_auc: 0.9833 - val_precision: 0.9307 - val_recall: 0.9307
# Epoch 41/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.0853 - accuracy: 0.9679 - auc: 0.9952 - precision: 0.9679 - recall: 0.9679 - val_loss: 0.2635 - val_accuracy: 0.9197 - val_auc: 0.9675 - val_precision: 0.9197 - val_recall: 0.9197
# Epoch 42/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1012 - accuracy: 0.9642 - auc: 0.9930 - precision: 0.9642 - recall: 0.9642 - val_loss: 0.1359 - val_accuracy: 0.9526 - val_auc: 0.9865 - val_precision: 0.9526 - val_recall: 0.9526
# Epoch 43/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1120 - accuracy: 0.9642 - auc: 0.9911 - precision: 0.9642 - recall: 0.9642 - val_loss: 0.1542 - val_accuracy: 0.9398 - val_auc: 0.9875 - val_precision: 0.9398 - val_recall: 0.9398
# Epoch 44/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.0930 - accuracy: 0.9693 - auc: 0.9936 - precision: 0.9693 - recall: 0.9693 - val_loss: 0.1773 - val_accuracy: 0.9416 - val_auc: 0.9813 - val_precision: 0.9416 - val_recall: 0.9416
# Epoch 45/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.0881 - accuracy: 0.9693 - auc: 0.9948 - precision: 0.9693 - recall: 0.9693 - val_loss: 0.1712 - val_accuracy: 0.9507 - val_auc: 0.9796 - val_precision: 0.9507 - val_recall: 0.9507
# Epoch 46/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.0903 - accuracy: 0.9670 - auc: 0.9944 - precision: 0.9670 - recall: 0.9670 - val_loss: 0.2492 - val_accuracy: 0.9179 - val_auc: 0.9709 - val_precision: 0.9179 - val_recall: 0.9179
# Epoch 47/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1012 - accuracy: 0.9651 - auc: 0.9923 - precision: 0.9651 - recall: 0.9651 - val_loss: 0.2035 - val_accuracy: 0.9471 - val_auc: 0.9761 - val_precision: 0.9471 - val_recall: 0.9471
# Epoch 48/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1009 - accuracy: 0.9637 - auc: 0.9930 - precision: 0.9637 - recall: 0.9637 - val_loss: 0.2251 - val_accuracy: 0.9234 - val_auc: 0.9738 - val_precision: 0.9234 - val_recall: 0.9234
# Epoch 49/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.1005 - accuracy: 0.9665 - auc: 0.9923 - precision: 0.9665 - recall: 0.9665 - val_loss: 0.1625 - val_accuracy: 0.9434 - val_auc: 0.9817 - val_precision: 0.9434 - val_recall: 0.9434
# Epoch 50/50
# 69/69 [==============================] - 95s 1s/step - loss: 0.0855 - accuracy: 0.9752 - auc: 0.9944 - precision: 0.9752 - recall: 0.9752 - val_loss: 0.1967 - val_accuracy: 0.9343 - val_auc: 0.9794 - val_precision: 0.9343 - val_recall: 0.9343

# %%
evaluation_result = densenet121_model.evaluate(test_generator)
# Out:
# 18/18 [==============================] - 1s 70ms/step - loss: 0.2490 - accuracy: 0.9221 - auc: 0.9711 - precision: 0.9221 - recall: 0.9221

# %%
def plot_metrics(epochs, train_metric, val_metric, subplot_title, y_label):
    plt.plot(epochs, train_metric, label='Training ' + y_label)
    plt.plot(epochs, val_metric, label='Validation ' + y_label)
    plt.title(subplot_title)
    plt.xlabel('Epoch')
    plt.ylabel(y_label)
    plt.legend()

metrics = {
    'Accuracy': ('accuracy', 'val_accuracy'),
    'Loss': ('loss', 'val_loss'),
    'AUC': ('auc', 'val_auc'),
    'Precision': ('precision', 'val_precision'),
    'Recall': ('recall', 'val_recall')
}

epochs = range(len(densenet121_history.history['accuracy']))

plt.figure(figsize=(12, 12))

for i, (metric_name, (train_key, val_key)) in enumerate(metrics.items(), 1):
    plt.subplot(3, 2, i)
    plot_metrics(epochs, densenet121_history.history[train_key], densenet121_history.history[val_key], f'Training and Validation {metric_name}', metric_name)

plt.tight_layout()
plt.show()

# %%
densenet121_model.save(r'model_densenet121.h5')

loaded_model = tf.keras.models.load_model(r'model_densenet121.h5')

evaluation_result = loaded_model.evaluate(test_generator)
# Out:
# /environment/miniconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 18/18 [==============================] - 3s 57ms/step - loss: 0.2490 - accuracy: 0.9221 - auc: 0.9711 - precision: 0.9221 - recall: 0.9221

# %%
all_images = []
all_true_labels = []

for _ in range(test_generator.samples // test_generator.batch_size):
    images, true_labels = next(test_generator)
    all_images.extend(images)
    all_true_labels.extend(true_labels)

all_images = np.array(all_images)
all_true_labels = np.argmax(np.array(all_true_labels), axis=1)
predictions = loaded_model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)


conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 17/17 [==============================] - 2s 30ms/step

# %%
TP = conf_matrix[1, 1]
TN = conf_matrix[0, 0]
FP = conf_matrix[0, 1]
FN = conf_matrix[1, 0]

recall = TP / (TP + FN)
precision = TP / (TP + FP)
sensitivity = recall
specificity = TN / (TN + FP)

plt.bar(['Recall', 'Precision', 'Sensitivity', 'Specificity'], [recall, precision, sensitivity, specificity])
plt.ylim([0, 1])
plt.ylabel('Score')
plt.title('Evaluation Metrics')
plt.show()

print(recall, precision, sensitivity, specificity)
# Out:
# 0.991869918699187 0.8714285714285714 0.991869918699187 0.8686131386861314

# %%
predicted_labels = np.argmax(predictions, axis=1)
fpr, tpr, thresholds = roc_curve(all_true_labels, predictions[:, 1])  
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
precision, recall, _ = precision_recall_curve(all_true_labels, predictions[:, 1])
pr_auc = auc(recall, precision)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='darkorange', lw=2, label=f'PR curve (area = {pr_auc:.2f})')
# plt.plot([0, 1], [1, 0], color='navy', lw=2, linestyle='--') 
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
f1 = f1_score(all_true_labels, predicted_labels)

print("F1 Score:", f1)
# Out:
# F1 Score: 0.9277566539923955

# %%
kappa_score = cohen_kappa_score(all_true_labels, predicted_labels)

# Print the Kappa score
print("Kappa Score:", kappa_score)
# Out:
# Kappa Score: 0.854449027695934

# %%
history_df1 = pd.DataFrame(densenet121_history.history)

history_df1.to_csv('model_ResNet.csv', index=False)

# %%
precision, recall, _ = precision_recall_curve(all_true_labels, predictions[:, 1])
auc_pr = auc(recall, precision)

# 绘制AUC-PR曲线
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='darkorange', lw=2, label=f'AUC-PR = {auc_pr:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='lower left')
plt.show()
